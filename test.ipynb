# %%
import requests

url = "https://www.baidu.com"
response=requests.get(url)
print(response.text)

# %%
class person:
    pass
p = person()
print(p)
class newperson:
    def sayhi(self):
        print("hello")
p1 = newperson()
p1.sayhi()


count = 2
total = 0
while (count < 100):
    if count % 2 == 0:
        total -= count
    else:
        total += count
    count += 1
    print(total)

import random
secret = random.randint(1,100)
print("guess the number")
truenum = int(input("enter you number"))
while True:
    truenum = int(input("enter you number"))
    if (truenum > secret):
        print("bigger guess")
    elif (truenum < secret):
        print("smaller guess")
    else:
        print("you guess right")
        break

# %%
# name = "\tsteam \neric"
# print(name.lstrip()) #（）内部放参数 l为左 r为右 默认清除空格
# print(name.rstrip())
# print(name.strip())

# 将任意两个数相除时，结果总是浮点数，即便这两个数都是整数且能整除：
# >> > 4 / 2
# 2.0
#
# 在其他任何运算中，如果一个操作数是整数，另一个操作数是浮点数，结果也总是浮点
# 数：
# >> > 1 + 2.0
# 3.0
# >> > 2 * 3.0
# 6.0
# >> > 3.0 ** 2
# 9.0
#
# 无论是哪种运算，只要有操作数是浮点数，Python默认得到的总是浮点数，即便结果原
# 本为整数也是如此。
# universal_number =14_000_000_000
# print(universal_number) #当你打印这种使用下划线定义的数时，Python不会打印其中的下划线
# import this #python之禅
# print(this.d)
# MAXNUM = 1000 #在代码中，要指出应将特定的变量视为常量，可将其字母全部大写。
# x,y,z =0,0,0#可以这样进行赋值

# m = ['1','2',"3"]
# print(m[0])
# m[0]= 5 #可任意修改列表任意序列的值
# print(m[0])
# m.append("4")#在末尾插入元素
# m.insert(1,"5")#可以选择任意位置插入元素
#
# del m[0] #可以选择索引来删除元素
# m.pop()#删除末尾的元素  可以选择索引()
#  #如果你不确定该使用del 语句还是pop() 方法，下面是一个简单的判断标准：如果
# # 你要从列表中删除一个元素，且不再以任何方式使用它，就使用del 语句；如果你要在删除元素后还能继续使用它，就使用方法pop()
# m.remove("4")#根据值来进行删除 但是只能删除第一个指定的值,多个需要循环
# pl = ["re","12","dfda","231"]
# print(f"{pl}是我邀请的人")
# print(f"{pl[0]}无法收到邀请")
# del pl[0]
# print(f"{pl}是最新名单")

# s = ['scss',"da",'12',"a"]
# print(sorted(s)) #sort和sorted进行排序,sort永久进行排序,sorted进行临时排序
# sorted(s).reverse() #reverse=True：我要降序排列 reverse()：把这个列表倒过来
# s.sort(reverse=True)
#title()方法是首字母大写,其余小写

# pizzas = ['fruit','bake','pepperoni']
# for pizza in pizzas:
#     print(f"i like {pizza} pizza")

# nums = []
# for num in range(1,1000001):
#     nums.append(num)
# print(nums)
# print(max(nums))
# print(min(nums))
# print(sum(nums))

# people ={"city":"beijing","age":5,"first_name":"ni","last_name":"ge"}
# # print(people["city"])
# # print(people["age"])
# # print(people["first_name"])
# # print(people["last_name"])
# for k,v in people.items():
#     print(f"{k},{v}分别是key和value")#遍历所有键值对
# # .items() 方法：
# # 返回字典中所有键值对的视图
# # 每个键值对是一个元组 (key, value)
# #如果指定的键有可能不存在，应考虑使用方法get() ，而不要使用方括号表示法。
#
# for k in people.keys(): #遍历字典时会默认遍历所有的键
#     print(k.title())
# for v in people.values():
#     print(v.title())
#
# print(sorted(people.items()))#列出键之前把键进行的顺序进行排序

#
# p = {"f":1,"s":2,"t":3,"f":1}
# for l in set(p.values()):#为剔除重复项，可使用集合set()
#     print(l)

#列表储存在字典中，或者字典储存在列表中，甚至在字典里嵌套字典，这个被称作嵌套
# aliens = []
# for i in range(30):
#     new = {'color':"red","speed":100,"points":6}
#     aliens.append(new)
#
# print(aliens)

# pizza = { #字典里插入列表
#     'crust':'thick',
#     'toppings':['mushrooms','extra cheese'],
# }
# print(f"You ordered a {pizza['crust']}-crust pizza "
#       "with the following toppings:")
#
# for topping in pizza['toppings']:#遍历字典里的列表
#     print(""+topping)
#
# users = { #字典嵌套字典
#     'aeinstein': {
#         'first': 'albert',
#         'last': 'einstein',
#         'location': 'princeton',
#     },
#
#     'mcurie': {
#         'first': 'marie',
#         'last': 'curie',
#         'location': 'paris',
#     },
#
# }
#
# for username, user_info in users.items():
#     print(f"\nUsername: {username}")
#     full_name = f"{user_info['first']} {user_info['last']}"
#     location = user_info['location']
#     print(f"\tFull name: {full_name.title()}")
#     print(f"\tLocation: {location.title()}")

# unconfirmed_users = ['alice','brain','candace']
# confirmed_users = []
#
# while unconfirmed_users:
#     current_user = unconfirmed_users.pop()
#     print(f"Verifying user :{current_user.title()}")
#     confirmed_users.append(current_user)
#
# print("\nThe following users are confirmed:")
# for confirmed in confirmed_users:
#     print(f"there are confirmed users:{confirmed.title()}")

# pets = ['dog', 'cat', 'dog', 'goldfish', 'cat', 'rabbit', 'cat']
# print(pets)
# while 'cat' in pets:
#     pets.remove('cat')
# print(pets)

# %%
#切片
qiepian = ['1','sdhj','123sd','fsdaas','safdhjd']
print(qiepian[1:4])
print(qiepian[-3:])#从开头开始往倒数第一个数，不及第一个
print(qiepian[:-3])#

#🎯 易错点2：负索引就像"倒数座位"
座位 = ['小明', '小红', '小刚', '小丽', '小王']
# 正索引: 0      1      2      3      4
# 负索引: -5     -4     -3     -2     -1
#         ↑      ↑      ↑      ↑      ↑
#      "第一排" "第二排" "第三排" "倒数第二" "倒数第一"
#易错：[-3:-1] 不包含最后一个！
print(座位[-3:-1])  # ['小刚', '小丽'] 没有小王！
# 从倒数第三个小刚开始，到倒数第一个小王前结束

nu = ['charles','marina','michael','florence','eli']
print("Here are the first three players on my team:")
for player in nu[:3]:
    print(player.title())

old = nu[:] #适用于一维数组，需要使用独立的副本时

# %%
re = {}
con = True
while con:
    name = input("\nplease input your name")
    r = input("please input your favorite hobby")

    re[name] = r

    repeat = input("\ncontinue?(yes or no) ")
    if repeat == "no":
        con = False
print("\n done survey")
for i in re:
    print(re)

def display_message(p):
    print(p)
q = "function"
display_message(q)

def favorite_book(title):
    print(f"one of my favorite books is {title}")

b = "green tale"
favorite_book(b)

# %%
#传递实参的方法分别为 位置实参，关键字实参和默认参数
def describe_pet(animal_type,pet_name): #此处位置实参有问题导致输出相反
    print(f"\n I have a {animal_type}.")
    print(f"my {animal_type}'s name is {pet_name.title()}")

describe_pet('harry','hamaster')

def describe_pet(animal_type,pet_name):
    print(f"\n I have a {animal_type}.")
    print(f"my {animal_type}'s name is {pet_name.title()}")
describe_pet(animal_type='hamaster',pet_name='harry')#此处关键字的顺序无须专门进行调整

def describe_pet(pet_name,animal_type='dog',):#个函数调用的输出与前一个示例相同。只提供了一个实参'willie' ，这个实参将关联到函数定义中的第一个形参pet_name 。由于没有给animal_type 提供实参，Python将使用默认值'dog' 。
    print(f"\n I have a {animal_type}.")
    print(f"my {animal_type}'s name is {pet_name.title()}")
describe_pet("willie")

# %%
""" 练习列表
todo = []
while True:
    print("\n请选择操作")
    print("1.注意事项")
    print("2.查看所有事项")
    print("3.删除事项")
    print("4.删除程序")

    choice = input("请输入你的选择")
    if choice == "1": #添加事项
        item= input("请输入要添加的事项")
        todo.append(item)
        print(f"{item}已成功添加")
    elif choice == "2": #查看事项
        if not todo:
            print("当前没有待办事项")
        else :
            for index,item in enumerate(todo):
                print(f"{index+1}. {item}")
        print("-------------------------------")
    elif choice == "3":
        if not todo:
            print("没有事项删除")
            continue
        try:
            for index,item in enumerate(todo):
                print(f"{index+1}. {item}")

            item_num=int(input("请输入要删除的事项编号"))

            if 1 <= item_num <= len(todo):
                remove_item = todo.pop(item_num - 1)
                print(f"{remove_item}已被删除")
            else :
                print("无效编号")
        except ValueError:
            print("请输入正确编号")
    elif choice == "4":
        print("感谢使用")
        break
    else :
        print("无效选择") """
# from http.client import responses

# from prometheus_client.decorator import append


chengji ={}
while True:
    print("开始运行学生成绩管理系统，请选择你所需要的功能")
    print("1.录入成绩")
    print("2.查询成绩")
    print("3.显示成绩单")
    print("4.计算平均分")
    print("5.删除学生")
    print("6.退出系统")
    num = int(input("此处输入功能代码"))#这里需要使用try except来防止valueerror
    if num == 1:
        stdname=input("请输入你录入学生的姓名")
        grade =int(input("请输入你所需要写入的成绩"))
        if stdname in chengji:
            print(f"{stdname}已存在，成绩将从{chengji[stdname]}更新为{grade}")
        else :
            print(f"为{stdname}新生录入")
        try:
            chengji[stdname]=grade
            print(f"已成功录入{stdname}为{grade}")
        except ValueError:
            print("错误，数字不有效")
            continue
    elif num == 2:
        print("请输入你所要查询的学生名字")
        stdname1 = input("这里输入学生名字")
        if stdname1 in chengji:
            grade1 = chengji[stdname1]
            print(f"{chengji}的成绩是{grade1}")
        else:
            print("此学生不存在，请重新输入")
            continue
    elif num == 3:
        print(f"以下为成绩单{chengji}")
        continue
    elif num == 4:
        if not chengji:
            print("当前没有成绩，无法计算")
        else:
            all_score = chengji.values()
            total = sum(all_score)
            count = len(chengji)
            avg = total/count
            print(f"{count},{avg}")
            continue
    elif num == 5:
        print("请输入你要删除的学生")
        stdname2 = input("这里输入你要删除的学生名字")
        if stdname2 in chengji:
            re =  chengji.pop(stdname2)
            print(f"{stdname2}的{re}已被删除")
        else :
            print(f"字典里没有{stdname2}的成绩")
            continue
    elif num == 6:
        print("感谢使用")
        break
    else:
        if num not in [1,2,3,4,5,6]:
            print("无效应用代码，请重新输入")
            continue

# %%
def make_shirt(size,string="I love Python"):
    print(f"这件衣服的尺码是{size}，上面写的是{string}")

make_shirt(size='big')
make_shirt(size='medium')
make_shirt('small','wtfwhoami')

def describe_city(city,country):
    print(f"{city} is in {country}.")

describe_city('beijng','china')
def city_counter(city,country):
    print(f"{city.title()},{country.title()}")
city_counter("santiago","chile")

# %%
class dog :#类的练习
    def __init__(self,name,age):
        self.name=name
        self.age=age
    def sit(self):
        print(f"{self.name} is now sitting")
    def roll_over(self):
        print(f"{self.name} is now rolling over")

new_dog = dog('willie',6)
new_dog.sit()
new_dog.roll_over()

# %%
import pizza#通过在一个文件夹下导入写的py文件，就可以在这个文件使用导入文件中所有的函数
from pizza import make_pizza as pz#导入指定函数 as 可以给模块指定别名 *号导入所有函数
pizza.make_pizza(16,'pepperoni')
pizza.make_pizza(12,'mushroom','green pepper','extra cheese')

# %%
import string
import random
def generete(length:int = 10):#length后面的int=10是参数注解
    alphabet = string.ascii_letters + string.digits + string.punctuation
    password =''.join(random.choice(alphabet)for i in range(length))
    return password

import random
import string

all = string.digits + string.ascii_letters
def genercodes(*,code_len=6):
    return ''.join(random.choices(all,k=code_len))
for _ in range(10):
    print(genercodes())

# %%
def is_iris(number:int)->bool:  #水仙花数解一
    if number > 999 or number < 100 :
        return False
    number = str(number)
    gewei = int(number[2])
    shiwei = int(number[1])
    baiwei = int(number[0])
    if gewei**3 + shiwei**3 + baiwei**3 ==int(number):
        return True
    return False
print(is_iris(153))
print(is_iris(154))

def is_iris(number:int)->bool: 
    if number > 999 or number < 100 :
        return False
    number = number
    gewei = number%10
    shiwei = number//10%10
    baiwei = number//10//10%10
    if gewei**3 + shiwei**3 + baiwei**3 ==number:
        return True
    return False
print(is_iris(153))
print(is_iris(154))

# %%
word_counts= {}
print("单词计数器")
try:
    with open("encode.txt",'r') as file:
        for line in file:
            words = line.strip().lower().split()
            for word in words:
                if word in word_counts:
                    word_counts[word] += 1
                else:
                    word_counts[word] = 1


    print("result below")
    for word,count in word_counts.items():
        print(f"{word}: {count}次")

except FileNotFoundError:
    print("请确保脚本文件在同一文件夹下")

# %%
a = 11  #全局和局部
b = 21
def testfunc():
    global a # 使用全局a
    a = 10 
    b = 20
    return a,b
c,d = testfunc()
print(a,b,c,d)#10 21 10 20

# %%
class Car:#类的使用
    def __init__(self,make,model,year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0
    
    def get_descriptive_name(self):
        long_name = f'{self.year} {self.make} {self.model}'
        return long_name.title()
    
    def read_odometer(self):
        print(f"This car has {self.odometer_reading} miles on it.")
    
    def update_odometer(self,mileage):
        if mileage >= self.odometer_reading:
            self.odometer_reading = mileage
        else :
            print("you can't roll back an odometer!")
    
    def increment_odometer(self,miles):
        self.odometer_reading += miles

class ElectricCar(Car):
    def __init__(self,make,model,year):#初始化父类的属性
        super().__init__(make,model,year) #super()是一个特殊的函数，能够调用父类的方法
        self.battery_size =75
    def describe_battery(self):
        print(f"This car has a {self.battery_size}-Kwh battery ")
my_tesla = ElectricCar('tesla','model s',2019)
print(my_tesla.get_descriptive_name())
my_tesla.describe_battery()

# %%
def find_min_max(numbers):#找出最大最小值
    min = numbers[0]
    max = numbers[0]
    if not numbers:
        return None
    else :
        for i in numbers[1:]:
            if i < min:
                min = i
            if i > max:
                max = i
        return (max,min)
    pass

print(find_min_max([4,2,9,5,7,1]))

# %%
import nmap #扫描器
nm = nmap.PortScanner()
nm.scan('127.0.0.1','22-443')

for host in nm.all_hosts():
    print('Host : %s (%s)' %(host, nm[host].hostname()) )
    print('State : %s' % nm[host].state())
    for proto in nm[host].all_protocols():
        print('Protocol : %s' % proto)
        lport = nm[host][proto].keys()
        for port in lport:
            print('port : %s\tstate :  %s' % (port,nm[host][porto][port]['state']))

# %%
import socket #套接字
import sys

class Client:
    def __init__(self,host):
        self.host = host
    def connet(self):
        try :
            s = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
        except socket.error as e :
            print("Failed to create socket.Error: %s"%e)
        
        sys.exit

if __name__ == '__main__':
    cl = Client('www.baidu,com')
    cl.connet

# %%
import socket #套接字
import sys

class Client:
    def __init__(self,host):
        self.host = host
    def connet(self):
        try :
            s = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
        except socket.error as e :
            print("Failed to create socket.Error: %s"%e)
        
        sys.exit

if __name__ == '__main__':
    cl = Client('www.baidu,com')
    cl.connet

# %%
class Restaurant:
    def __init__(self,name,cuisine):
        self.name=name
        self.cuisine=cuisine
        self.number_served = 0
        
    def describe_restaurant(self):
        print(f"这是一家{self.name}餐厅，拥有{self.cuisine}菜品")
        
    def open_restaurant(self):
        print(f"这家{self.name}已经开业")
    def set_number_served(self,number_served):
        if name:
            number_served += 1
res = Restaurant("zhongye","chaoliji")
de = res.describe_restaurant()
op = res.open_restaurant()

# %%
class User:
    def __init__(self,first_name,last_name):
        self.first_name = first_name
        self.last_name = last_name
    def greet_user(self) :
        print(f"sayhi to the{self.first_name},{self.last_name}")
    def describe_user(self) :
        print(f"the first name is {self.first_name} the last_name is {self.last_name}")
will = User("saewa","fddsaf")
print(will.greet_user())
print(will.describe_user())

# %%
#直接修改实例的属性或者在类中找编写方法来进行修改
class Car:#类的使用
    def __init__(self,make,model,year):
        self.make = make
        self.model = model
        self.year = year
        self.odometer_reading = 0 #此处添加一个随时间变化的属性，用来存储汽车的总里程
        
    def get_descriptive_name(self):
        long_name = f'{self.year} {self.make} {self.model}'
        return long_name.title()

    def read_odometer(self):
        print(f"This car has {self.odometer_reading} miles on it.")

    def update_odometer(self,mileage):
        self.odometer_reading = mileage
    
my_new_car = Car('audi','a4',2019)
print(my_new_car.get_descriptive_name())

# %%
import os #文件练习
print(os.getcwd())

# file = open(r'D:/PythonProject1/网安/text.txt','r')
# print(file.read())
# file.close()
# with open('pi_digits.txt') as file_object:
#     contents = file_object.read()
# print(contents)
with open('pi_digits.txt') as file:
    contents = file.read()
print(contents.rstrip())

# %%
filename = 'pi_digits.txt'
with open(filename) as file:
    lines = file.readlines()
pi_string = ''
for line in lines:
    pi_string += line.rstrip()
print(pi_string)
print(len(pi_string))

# %%
filename = 'pi_digits.txt'
with open(filename) as file:
    lines = file.readlines()
pi_string = ''
for line in lines:
    pi_string += line.strip()
print(pi_string)
print(len(pi_string))

# %%
filename = 'program.txt'
with open(filename,'w') as file:
    file.write("I love programming.")

# %%
filename = 'pi_digits.txt'
with open(filename,'a') as file:#a不覆盖源文件的内容，w覆盖源文件的内容
    file.write('11111111111111111111111\n')

# %%
filename = 'guest.txt'
with open(filename,'a') as file:
    file.write((input('请输入你的名字')))

# %%
filename = 'guest_book.txt'

# 先显示已有的访客
try:
    with open(filename, 'r', encoding='utf-8') as file:
        content = file.read()
        if content:
            print("=== 已有访客 ===")
            print(content)
except FileNotFoundError:
    print("这是第一次使用访客簿")

# 添加新访客
with open(filename, 'a', encoding='utf-8') as file:
    while True:
        name = input('请输入你的名字（输入q退出）: ')
        if name.lower() == 'q':
            break
        file.write(name + '\n')
        print(f'欢迎你 {name}！')

# %%
filename = 'whoiswoldy.txt'
with open(filename,'a+') as file:
    f = file.read()
    print(f)

# %%
list = [11,22,33,44,55,66,77,88,99,90]
list1 =[]
list2 =[]
for i in list:
    if i > 66:
        list1.append(i)
    elif i <66:
        list2.append(i)
    else:
        pass #return只能在函数当中使用，所以需要使用pass来进行
list3 = {'k1':list1,'k2':list2}
print(list3)

# %%
#查找列表中元素，移除每个元素的空格，并查找以 a或A开头 并且以 c 结尾的所有元素。
li =["alec"," aric","Alex","Tony","rain"]
tu =("alec","aric","Alex","Tony","rain")
dic = {'k1': "alex", 'k2': ' aric', "k3": "Alex", "k4": "Tony"}
tem = []

for i in range(0,len(li)):
    li[i]=li[i].strip()
    if li[i].endswith('c') and li[i].capitalize().startswith('A'):
        tem.append(li[i])

# %%
li = ["手机", "电脑", '鼠标垫', '游艇']
a =input("请输入你所选商品的序号")

for index,text in enumerate(li,1):
    print(index,text)

inp = input("请选择需要购买的商品")
inp_num =int(inp)
print(li[inp_num-1])

# %%
goods = [
    {"name": "电脑", "price": 1999},
    {"name": "鼠标", "price": 10},
    {"name": "游艇", "price": 20},
    {"name": "美女", "price": 998},
]

num = int(input("请输入你的总资产"))
print(f"以下为商品\n{goods}")

# %%
import requests

kw = {'wd':'长城'}
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/54.0.2840.99 Safari/537.36"}
response = requests.get("http://www.baidu.com",params=kw,headers=headers)
print(response.text)
print(response.content)
print(response.content.decode())
print(response.url)
print(response.encoding)
print(response.status_code)

# %%
import string 
import random

def generate_password(numbers:int=10):
    alphabet = string.ascii_letters + string.punctuation + string.digits
    return ''.join(random.choice(alphabet)for i in range(numbers))
generate_password()

# %%
import socket
s1 = socket.socket()
s1.bind(("127.0.0.1",2345))
s1.listen()
str="hello world"
while 1:
    conn,address = s1.accept()
    print("a new connect from",address)
    conn.send(str.encode())
conn.close()

# %%
for i in range(1,5):
    for j in range(1,5):
        for k in range(1,5):
            if i != j and j != k and k != i:
                print(f"{i},{j},{k}")

# %%
#企业发放的奖金根据利润提成。利润(I)低于或等于10万元时，奖金可提10%；
# 利润高于10万元，低于20万元时，低于10万元的部分按10%提成，高于10万元的部分，可提成7.5%；
# 20万到40万之间时，高于20万元的部分，可提成5%；40万到60万之间时高于40万元的部分，可提成3%；
# 60万到100万之间时，高于60万元的部分，可提成1.5%，高于100万元时，超过100万元的部分按1%提成，
# 从键盘输入当月利润I，求应发放奖金总数？

# %%
if __name__ == "__main__":
    fib1 = 1
    fib2 = 1
    i = 1
    while i <= 15 :
        print("%8d  %8d" %(fib1,fib2),end="     ")
        if i % 2 == 0:
            print()
        fib1 = fib1 + fib2
        fib2 = fib1 + fib2
        i += 1

# %%
for i in range(1,10):
    for j in range(1,i+1):
        print(f"{i}*{j}={i*j}",end=" ")
    print(" ")

# %%
a = input("请输入你的四则运算符")
if "+" in a :
    p = "+"
    num1,num2 =a.split('+')
elif "-" in a:
    p = "-"
    num1,num2 =a.split('-')
elif '*' in a:
    p = '*'
    num1,num2 =a.split('*')
elif '/' in a:
    p = '/'
    num1,num2 =a.split('/')
else:
    print("错误：未找到支持的运算符")
    exit()

try:
       
    num1 =float(num1.strip())
    num2 =float(num2.strip())

    if p == '+':
        re = num1 + num2
    elif p == "-":
        re = num1 - num2 
    elif p == "*":
        re = num1 * num2
    elif p == "/":
        re = num1 / num2 
   
except ZeroDivisionError:
        print("0不能够作为除数")

# %%
import requests

url = 'https://httpbin.org/ip'
response = requests.get(url)
print(response.content)
print(response.status_code)
print(response.json())
data = response.json()
print(data["origin"])

# %%
import requests

url = 'https://jsonplaceholder.typicode.com/users'
params = {'username': "Bret" }
response = requests.get(url,params=params)
data = response #将响应对象赋值给data变量
a = data.json() #之后调用json的方法使json数据成为对象
print(a[0]) #在使用列表打印第一个元素

# %%
import requests

url = 'https://jsonplaceholder.typicode.com/posts'

post_data = {
    'title': '我的第一篇博客',
    'body': '这是使用 Python requests 库发布的内容。',
    'userId': 1
}
response = requests.post(url,data=post_data)
print(response.status_code)
print(response.content)
a = response.json()
print(a)

# %%
import requests

# 1. API 的基础 URL
base_url = "https://api.openweathermap.org/data/2.5/weather"

# 2. 获取用户输入
city = input('请输入你的城市名 (例如 beijing): ')

# 3. 你的 API Key (请确保它是有效的)
api_key = 'baa7aa7aa3ba72c78e81a29a2a32972e' 

# 4. 创建正确的参数字典
# 格式是 '键': 值
params = {
    'q': city,
    'appid': api_key,
    'units': 'metric', # API 文档要求是 'units' 而不是 'unit'
    'lang': 'zh_cn'  # (可选) 添加这个参数可以让描述变成中文
}

print(f"正在查询城市: {city} ...")

try:
    # 5. 发送 GET 请求，同时传入 URL 和参数
    response = requests.get(base_url, params=params)
    
    # 检查 HTTP 状态码，如果不是 2xx，则会引发异常
    response.raise_for_status() 

    # 6. 解析 JSON 数据
    data = response.json()

    # 7. 提取并打印所需信息
    weather_description = data['weather'][0]['description']
    current_temperature = data['main']['temp']

    print("\n查询成功！")
    print(f"天气状况: {weather_description}")
    print(f"当前温度: {current_temperature}°C")

# 8. 捕获可能发生的错误
except requests.exceptions.HTTPError as err:
    if response.status_code == 404:
        print(f"错误：找不到城市 '{city}'。请检查拼写是否正确。")
    elif response.status_code == 401:
        print("错误：API Key 无效或未激活。请检查你的 Key。")
    else:
        print(f"请求失败，HTTP 错误: {err}")
except requests.exceptions.RequestException as err:
    print(f"请求发生网络错误: {err}")
except KeyError:
    print("错误：返回的数据格式不符合预期，无法解析天气信息。")

# %% [markdown]
# 好的，既然你已经掌握了 `requests` 的基础，是时候进入真正有趣和实用的领域了！这些进阶挑战会模拟更真实的编程场景，涉及到 API 认证、处理分页数据和文件下载。
#
# ---
#
# ### 进阶挑战 1：带身份认证的天气查询 API
#
# 在真实世界中，绝大多数有用的 API 都需要某种形式的“身份认证”，以防止滥用并追踪使用情况。这个挑战将让你首次接触使用 **API 密钥 (API Key)**。
#
# **API 服务：** [OpenWeatherMap](https://openweathermap.org/)
# 这是一个非常流行的天气数据服务。你需要先免费注册一个账户，然后在你的账户后台找到你的 API Key。
#
# **目标：**
# 编写一个程序，可以查询任何用户输入的城市，并从 OpenWeatherMap 获取其当前的温度和天气状况。
#
# **关键概念：**
# *   API 密钥认证
# *   在 GET 请求中组合多个查询参数
# *   处理更复杂的 JSON 响应
#
# **步骤指南：**
# 1.  **注册并获取 API Key**：
#     *   访问 [OpenWeatherMap 官网](https://openweathermap.org/) 并注册一个免费账户。
#     *   登录后，在你的账户页面找到 "API keys" 标签页，复制系统为你生成的默认密钥。
#
# 2.  **阅读 API 文档**：
#     *   查看 [Current Weather Data API 文档](https://openweathermap.org/current)。这是开发者最重要的技能之一！
#     *   文档会告诉你 API 的 URL 是什么 (`https://api.openweathermap.org/data/2.5/weather`)，以及需要哪些必需的查询参数（如 `q` 用于城市名，`appid` 用于你的 API Key）。
#
# 3.  **编写脚本**：
#     *   导入 `requests` 库。
#     *   让用户通过 `input()` 输入一个城市名。
#     *   创建一个参数字典 `params`，它至少需要包含三个键：
#         *   `q`: 用户输入的城市名。
#         *   `appid`: 你从网站上复制的 API Key。
#         *   `units`: 设置为 `'metric'`，这样温度就会以摄氏度为单位返回。
#     *   使用 `requests.get()` 并传入 `params` 字典来发送请求。
#
# 4.  **处理响应**：
#     *   **务必检查状态码！** 如果是 `401`，通常意味着你的 API Key 有问题。如果是 `404`，说明城市没有找到。
#     *   如果请求成功 (`200`)，解析返回的 JSON 数据。
#     *   仔细观察 JSON 的结构。你需要从中提取出：
#         *   天气描述：在 `weather` 列表的第一个元素的 `description` 字段里。
#         *   当前温度：在 `main` 字典的 `temp` 字段里。
#     *   将这些信息友好地打印出来。
#
# **提示：**
# *   不要将你的 API Key 硬编码在代码里然后分享给别人。在更高级的项目中，我们会使用环境变量来管理密钥。
# *   返回的 JSON 嵌套层级较多，`print()` 整个 JSON 出来先观察一下结构，对你寻找数据非常有帮助。
#
# ---
#
# ### 进阶挑战 2：处理分页数据 - 获取 GitHub 用户的所有关注者
#
# 当你请求一个拥有大量数据的资源时（例如一个名人的所有社交媒体粉丝），API 不会一次性返回所有数据，而是会进行**分页**。你一次只能获取一“页”数据，然后需要根据指引去请求下一页，直到所有数据都获取完毕。
#
# **API 服务：** [GitHub API](https://docs.github.com/en/rest)
#
# **目标：**
# 编写一个脚本，获取一个指定 GitHub 用户（例如 `torvalds`，Linux 的创始人）的**所有**关注者 (followers) 的登录名。
#
# **关键概念：**
# *   处理分页 (Pagination)
# *   使用 `requests.Session` 对象
# *   循环发送多次请求
#
# **步骤指南：**
# 1.  **确定 API 端点**：
#     *   查阅 GitHub API 文档，找到获取用户关注者列表的端点。它通常是 `https://api.github.com/users/{username}/followers`。
#
# 2.  **使用 `requests.Session`**：
#     *   当需要对同一个域名发送多次请求时，使用 `Session` 对象会更高效，因为它可以保持连接和 cookies。
#     *   创建会话：`session = requests.Session()`。后续的请求都用 `session.get()` 而不是 `requests.get()`。
#
# 3.  **实现分页逻辑**：
#     *   GitHub API 的分页非常友好。你可以通过一个 `page` 查询参数来控制获取第几页的数据，还有一个 `per_page` 参数控制每页显示多少条（最大为 100）。
#     *   使用一个 `while True` 无限循环来不断请求下一页。
#     *   在循环中：
#         *   设置 `params = {'page': current_page, 'per_page': 100}`。
#         *   发送 GET 请求。
#         *   解析返回的 JSON 数据（它是一个用户列表）。
#         *   **关键判断**：如果返回的列表是**空**的 (`[]`)，说明已经没有更多数据了，此时应该使用 `break` 退出循环。
#         *   如果列表不为空，就遍历这个列表，提取出每个用户的登录名 (`login`)，并添加到一个总的列表中。
#         *   不要忘记在循环的末尾将页码 `current_page` 加 1。
#
# 4.  **输出结果**：
#     *   循环结束后，打印你收集到的所有关注者的数量和他们的登录名。
#
# ---
#
# ### 进阶挑战 3：文件下载 - 下载并保存一张图片
#
# `requests` 不仅能处理文本和 JSON，还能处理任何类型的网络资源，包括图片、视频、PDF 等二进制文件。
#
# **目标：**
# 编写一个脚本，从网络上下载一张图片并将其保存到本地。
#
# **API/URL 源：** [Unsplash Source](https://source.unsplash.com/)
# 这个服务很酷，访问 `https://source.unsplash.com/random/800x600` 会随机重定向到一张 800x600 的图片。
#
# **关键概念：**
# *   处理二进制响应内容
# *   流式下载 (`stream=True`)
# *   将数据写入本地文件
#
# **步骤指南：**
# 1.  **定义图片 URL**：`url = 'https://source.unsplash.com/random/800x600'`
#
# 2.  **发送流式请求**：
#     *   在发送 GET 请求时，必须设置 `stream=True`。
#     *   `response = requests.get(url, stream=True)`
#     *   `stream=True` 的作用是：`requests` 不会立即下载全部内容并放到内存里，而是只下载响应头。这对于下载大文件至关重要，可以防止内存溢出。
#
# 3.  **检查请求是否成功**：老规矩，`if response.status_code == 200:`。
#
# 4.  **写入文件**：
#     *   使用 `with open('random_image.jpg', 'wb') as f:` 来打开一个文件。
#         *   `'random_image.jpg'` 是你希望保存的文件名。
#         *   `'wb'` 是关键，代表**以二进制写入 (Write Binary)** 模式。图片不是文本，必须用二进制模式。
#     *   使用 `for chunk in response.iter_content(chunk_size=8192):` 来迭代响应内容。
#         *   `iter_content()` 会以“块”为单位来获取数据，`chunk_size` 可以自定义每一块的大小（字节）。这进一步保证了内存效率。
#         *   在循环中，将每个 `chunk` 写入文件：`f.write(chunk)`。
#
# 5.  **给出提示**：
#     *   下载完成后，`print` 一条消息，告诉用户图片已成功保存。
#
# 完成这些挑战，你对 `requests` 的理解将远超普通初学者，并能用它来解决绝大多数的网络交互问题。祝你挑战成功！

# %%
#简易通讯录的设计
contacts =[]
print('以下为全部功能')
print('1. 添加 2. 查询 3. 删除 4. 显示所有 5. 退出')


while True:
    num = input("请选择你你需要的功能")#始终记住input的输入是字符串 需要进行强转类型
    capacity = int(num)

    if capacity == 1:
        insert_contacts()
    elif capacity == 2:
        select_contacts()
    elif capacity == 3:
        delete_contacts()
    elif capacity == 4:
        print_contacts()
    elif capacity == 5:
        break
    else:
        print("无效输入，请输入正确的功能代码")
    

def insert_contacts():
    print('请输入你的姓名和电话')
    name = input("此处输入名字")
    phone = input("此处输入电话")
    new_contact ={"name":name,"phone":phone}
    contacts.append(new_contact)
    print(f"插入{name}和{phone}成功")

def select_contacts():
    name_to_find = input("请输入你需要查询的名字: ")
    found = False  # 设置一个标志，记录是否找到了联系人

    for contact in contacts:
        # 比较字典中的 'name' 值和我们要找的名字
        if contact['name'] == name_to_find:
            print(f"找到了! {contact['name']} 的电话是: {contact['phone']}")
            found = True # 找到了，把标志设为 True
            break # 找到了就可以停止循环了

    # 在整个循环结束后，根据标志判断是否要打印“未找到”
    if not found:
        print(f"查询失败，通讯录中没有找到名为 '{name_to_find}' 的联系人。")

    print("---查询完成---")
    # 问题1 (变量覆盖): 你先用 name_selected 存储了用户输入的姓名，但紧接着在 for 循环中，
    # 你又写了 for name_selected in contacts。
    # 这导致 name_selected 这个变量在循环里被重新赋值为 contacts 列表中的每一个元素（也就是每一个联系人字典）。
    # 用户最初输入的名字就丢失了。
    # 修正：for 循环的临时变量需要换个名字，比如 contact。
    # 问题2 & 3 (访问方式错误): contacts 是一个列表，你不能通过 contacts["name"] 来访问它。
    # 你应该访问列表中的每一个元素（那个字典）的 'name' 键。
    # 修正：在循环里，contact 代表一个字典，所以你应该比较 contact['name'] 和用户输入的姓名。
    # 问题4 (打印逻辑): 如果找到了，应该打印这个联系人的电话 contact['phone']，
    # 或者整个联系人信息 contact。
    # 问题5 (错误提示时机): for 循环每遍历一个不匹配的联系人，你都会打印一次“查询失败”。
    # 正确的逻辑应该是：把整个列表都找完了，如果还没找到，才打印“查询失败”。
    
    # for name_selected in contacts: 
    #     if name_selected == contacts["name"]:
    #         print(contacts[name_selected])
    #     else :
    #         print("查询失败，检查输入是否是有误或者是通讯录当中没有")
    # print("完成查询")

def delete_contacts():
    name_to_delete = input("请输入你需要进行删除的名字: ")
    contact_to_remove = None # 用来存储将要被删除的那个字典
    
    for contact in contacts:
        if contact['name'] == name_to_delete:
            contact_to_remove = contact # 找到了，先存起来
            break # 停止查找

    # 循环结束后，再进行删除操作
    if contact_to_remove: # 如果 contact_to_remove 不是 None (意味着找到了)
        contacts.remove(contact_to_remove)
        print(f"成功删除联系人: {name_to_delete}")
    else:
        print(f"删除失败，通讯录中没有找到名为 '{name_to_delete}' 的联系人。")

    print("---删除操作完成---")
    
    #这里问题1 & 2：和上面完全一样，变量被覆盖，访问列表的方式也不对。
    #问题3 (remove 用法): list.remove(x) 是用来删除列表中第一个值为 x 的元素的。
    # 你应该删除的是你找到的那个字典，而不是一个字符串。
    # 另外，.remove() 方法是没有返回值的（或者说返回 None）
    # 所以 print(contacts.remove(...)) 不会打印出有用的信息
    
    
    # for named in contacts:
    #     if named == contacts["name"]:
    #         print(contacts.remove(contacts["name"]))
    #     else:
    #         print("无效名字值，请重新输入")
    # print("完成删除操作")

def print_contacts():
    if not contacts:
        print("通讯录为空")
    else :
        for contact in contacts:
            print(contact)

# %%
#文件读取练习
text = []
with open("sample.txt",'r',encoding='utf-8') as f :
    for line in f:
        text.append(line)
print(text)

# %%
encoded='19451c1a451c1d450a1c1a0a45121b1a1d' #简单异或脚本进行测试
key = '7a'
key_int = int(key,16)
a = encoded
b = bytes.fromhex(encoded)
decoded = bytearray()
for byte in b :
    decoded.append(byte ^ key_int)
print({decoded.decode()})

# %%
# code = input("请输入你的8位序列号")
# p1 = int(code[0:4])
# p2 = int(code[4:8])
for p1 in range(1000,10000):
    for p2 in range(0,9999):
        if ((p1 * 3 + 5) * (p2 -10) == 88888888):
            print(f"key is {p1}{p2}")

# %%
import gmpy2
import Crypto.Util.number

p = 63601
q = 73511
e = 65537
c = 123456789

n = p * q
phi = (p-1)*(q-1) 

print(f"n = {n}")
print(f"phi = {phi}")

d = gmpy2.invert(e,phi)
print(f"d = {d}")
m = pow(c,d,n)
print(f"flag is {m}")
print(Crypto.Util.number.long_to_bytes(m))#把大数转化成为字符串

# %%
string = "34sy_r3v3rs3"
result = ""
for char in string:
    if char == '3':
        result += 'e'
    elif char == "4":
        result += 'a'
    else :
        result += char
print(result)
# Out:
# easy_reverse

# %%
import base64
string = 'TlNTQ1RGe2Jhc2VfNjRfTlRXUTRaR0ROQzdOfQ=='
fin = base64.b64decode(string)
print(fin)

# %%
a = [0x34, 0x29, 0x29, 0x39, 0x2E, 0x3C, 0x01, 0x22, 0x15, 0x08, 
     0x25, 0x13, 0x09, 0x25, 0x18, 0x1B, 0x09, 0x13, 0x19, 0x25, 
     0x08, 0x1F, 0x0C, 0x1F, 0x08, 0x09, 0x1F, 0x07, 0x00, 0x00, 
     0x00, 0x00]

# 转换为十六进制字符串
hex_str = ''.join(f'{x:02x}' for x in a)
print(f"十六进制字符串: {hex_str}")

# 与固定值异或
xor_key = 0x7A  # 可以更改这个值
xor_result = [x ^ xor_key for x in a]
print(f"与 0x{xor_key:02x} 异或后的十六进制: {[f'{x:02x}' for x in xor_result]}")

# 尝试解码为字符串
decoded = ''.join(chr(x ^ xor_key) for x in a)
print(f"解码后的字符串: {decoded}")
# Out:
# 十六进制字符串: 342929392e3c0122150825130925181b09131925081f0c1f08091f0700000000
# 与 0x7a 异或后的十六进制: ['4e', '53', '53', '43', '54', '46', '7b', '58', '6f', '72', '5f', '69', '73', '5f', '62', '61', '73', '69', '63', '5f', '72', '65', '76', '65', '72', '73', '65', '7d', '7a', '7a', '7a', '7a']
# 解码后的字符串: NSSCTF{Xor_is_basic_reverse}zzzz

# %%
b =[0x49, 0x4B, 0x41, 0x47, 0x50, 0x42, 0x5F, 0x41, 0x1C, 0x16, 
  0x46, 0x10, 0x13, 0x1C, 0x40, 0x09, 0x42, 0x16, 0x46, 0x1C, 
  0x09, 0x10, 0x10, 0x42, 0x1D, 0x09, 0x46, 0x15, 0x14, 0x14, 
  0x09, 0x17, 0x16, 0x14, 0x41, 0x40, 0x40, 0x16, 0x14, 0x47, 
  0x12, 0x40, 0x14, 0x59]


# 转换为十六进制字符串
hex_str = ''.join(f'{x:02x}' for x in b)
print(f"十六进制字符串: {hex_str}")

# 与固定值异或
xor_key =  0x24 # 可以更改这个值


xor_result = [x ^ xor_key for x in b]
print(f"与 0x{xor_key:02x} 异或后的十六进制: {[f'{x:02x}' for x in xor_result]}")

# 尝试解码为字符串
decoded = ''.join(chr(x ^ xor_key) for x in b)
print(f"解码后的字符串: {decoded}")
# Out:
# 十六进制字符串: 494b414750425f411c164610131c40094216461c091010421d09461514140917161441404016144712401459
# 与 0x24 异或后的十六进制: ['6d', '6f', '65', '63', '74', '66', '7b', '65', '38', '32', '62', '34', '37', '38', '64', '2d', '66', '32', '62', '38', '2d', '34', '34', '66', '39', '2d', '62', '31', '30', '30', '2d', '33', '32', '30', '65', '64', '64', '32', '30', '63', '36', '64', '30', '7d']
# 解码后的字符串: moectf{e82b478d-f2b8-44f9-b100-320edd20c6d0}

# %%
with open('enc_0.txt','rb')as f: #读取从ida提取的字节txt
    data = f.read() #读取

key = 0x7a
result = b''#这里因为读取的是二进制数据所以需要使用b放在外面
for b in data: #遍历二进制字节
    xordata = b ^ key  #字节进行异或
    result += bytes([xordata]) #将结果进行加入字符串
print(result)
# Out:
# b'NSSCTF{Xor_is_basic_reverse}zzzz'

# %%
def rc4_decrypt(key, ciphertext):
    # Key Scheduling Algorithm (KSA)
    S = list(range(256))
    j = 0
    for i in range(256):
        j = (j + S[i] + key[i % len(key)]) % 256
        S[i], S[j] = S[j], S[i]

    # Pseudo-Random Generation Algorithm (PRGA)
    i = 0
    j = 0
    plaintext = []
    for byte in ciphertext:
        i = (i + 1) % 256
        j = (j + S[i]) % 256
        S[i], S[j] = S[j], S[i]
        k = S[(S[i] + S[j]) % 256]
        plaintext.append(byte ^ k)

    return bytes(plaintext)

def main():
    hex_string = "A71A68ECD82711CC8C9B16155CD2673E82ADCE75D4BC5756C28A52B86BD6CCF8A4BA722FE05715B92411"
    key_string = "RC4_1s_4w3s0m3"
    
    # 将十六进制字符串转换为字节
    ciphertext = bytes.fromhex(hex_string)
    # 将密钥字符串转换为字节
    key = key_string.encode()
    
    # 使用 RC4 解密
    decrypted_data = rc4_decrypt(key, ciphertext)
    
    # 尝试解码为 UTF-8 字符串
    try:
        plaintext = decrypted_data.decode('utf-8')
        print("解密后的明文:", plaintext)
    except UnicodeDecodeError:
        print("解密结果不是有效的 UTF-8 字符串，以十六进制显示:")
        print(decrypted_data.hex())

if __name__ == "__main__":
    main()
# Out:
# 解密后的明文: moectf{why_Rc4_haS_The_Rev32sabl3_pr0ceSS}

# %%
from Crypto.Cipher import ARC4
import binascii

def decrypt_with_pycryptodome(hex_string, key_string):
    ciphertext = binascii.unhexlify(hex_string)
    key = key_string.encode()
    
    # 创建 RC4 密码器并解密
    cipher = ARC4.new(key)
    plaintext = cipher.decrypt(ciphertext)
    
    return plaintext

# 使用示例
hex_string = "A71A68ECD82711CC8C9B16155CD2673E82ADCE75D4BC5756C28A52B86BD6CCF8A4BA722FE05715B92411"
key_string = "RC4_1s_4w3s0m3"

decrypted = decrypt_with_pycryptodome(hex_string, key_string)
print("解密结果:", decrypted.decode('utf-8'))
# Out:
# 解密结果: moectf{why_Rc4_haS_The_Rev32sabl3_pr0ceSS}
